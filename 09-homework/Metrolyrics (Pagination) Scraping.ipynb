# %% [markdown]
# # Scraping Metrolyrics
# ### PART 1

# %%
import requests
import pandas as pd
import re
from bs4 import BeautifulSoup

# %%
# Scrape all pages of search results for your musician, and save as a CSV file. Include the following fields:

# Song title
# URL
# Popularity
# Year
# Bonus: Make the popularity a normal number (e.g., 6)

# %%
def scrap_songs_by_artist(artist: str, total_pages: int):
    rows = []
    for num in range(1, total_pages + 1):
        url = f'http://www.metrolyrics.com/{artist}-alpage-{num}.html'
        print('Scraping', url)
        response = requests.get(url)
        doc = BeautifulSoup(response.text)
        songs = doc.tbody.find_all('tr', class_ = False)
        for song in songs:
            row = {}
            try:
                row['title'] = re.findall(r'(.+) Lyrics', song.find('td', class_ = False).a.text)[0]
            except:
                pass
            try:
                row['url'] = song.a['href']
            except:
                pass
            try:
                row['year'] = song.find('td', class_ = False).find_next_sibling('td').text
            except:
                pass
            try:
                row['popularity'] = re.findall(r'popular(\d)', song.span['class'][1])[0]
            except:
                pass
            rows.append(row)
        df = pd.DataFrame(rows)
    return df

# %%
oasis_songs = scrap_songs_by_artist('oasis', 3)
oasis_songs.head()
# Out:
# Scraping http://www.metrolyrics.com/oasis-alpage-1.html
# Scraping http://www.metrolyrics.com/oasis-alpage-2.html
# Scraping http://www.metrolyrics.com/oasis-alpage-3.html
#   popularity                           title  \
# 0          0  (Get Off Your) High Horse Lady
# 1          1               (I Got) The Fever
# 2          0      (Probably) All in the Mind
# 3          4  (You've Got) A Heart Of A Star
# 4          1                A Bell Will Ring
#
#                                                  url  year
# 0  http://www.metrolyrics.com/get-off-your-high-h...  2008
# 1  http://www.metrolyrics.com/i-got-the-fever-lyr...  2007
# 2  http://www.metrolyrics.com/probably-all-in-the...  2008
# 3  http://www.metrolyrics.com/youve-got-a-heart-o...  2007
# 4  http://www.metrolyrics.com/a-bell-will-ring-ly...  2005

# %%
oasis_songs = oasis_songs[['title', 'year', 'url', 'popularity']]
oasis_songs.to_csv('Metrolyrics_oasis_songs.csv', index = False)

# %% [markdown]
# ### PART 2

# %%
# Metrolyrics, Part 2: Scrape the lyrics pages

# Then, open your search results csv, and scrape the following field:

# Lyrics
# Merge with your original song information and save as a new CSV file

# Tip: If you use .find for your lyrics, they'll have a bunch of ads inside! 
# You can use the ingredients/directions trick from above, or you can clean them with regex.

# %%
df = pd.read_csv('Metrolyrics_oasis_songs.csv')
df.head()
# Out:
#                             title  year  \
# 0  (Get Off Your) High Horse Lady  2008
# 1               (I Got) The Fever  2007
# 2      (Probably) All in the Mind  2008
# 3  (You've Got) A Heart Of A Star  2007
# 4                A Bell Will Ring  2005
#
#                                                  url  popularity
# 0  http://www.metrolyrics.com/get-off-your-high-h...           0
# 1  http://www.metrolyrics.com/i-got-the-fever-lyr...           1
# 2  http://www.metrolyrics.com/probably-all-in-the...           0
# 3  http://www.metrolyrics.com/youve-got-a-heart-o...           4
# 4  http://www.metrolyrics.com/a-bell-will-ring-ly...           1

# %%
def get_lyrics(data):
    print('Scraping lyrics of', data['title'])
    response = requests.get(data['url'])
    doc = BeautifulSoup(response.text)
    row = {}
    
    title = doc.find(class_ = 'banner-heading').h1.text
    row['title'] = re.findall(r'(.+) Lyrics.+', title)[0]
    
    body = doc.find('div', id = 'lyrics-body-text')
    verse = body.find_all(class_ = 'verse')
    verse = '\n'.join([line.text for line in verse])
    row['verse'] = verse
    return pd.Series(row)

# %%
oasis_lyrics = df.apply(get_lyrics, axis = 1)
# Out:
# Scraping lyrics of (Get Off Your) High Horse Lady
# Scraping lyrics of (Get Off Your) High Horse Lady
# Scraping lyrics of (I Got) The Fever
# Scraping lyrics of (Probably) All in the Mind
# Scraping lyrics of (You've Got) A Heart Of A Star
# Scraping lyrics of A Bell Will Ring
# Scraping lyrics of A Quick Peep
# Scraping lyrics of Acquiesce
# Scraping lyrics of Ain't Got Nothin
# Scraping lyrics of Alice
# Scraping lyrics of Alive
# Scraping lyrics of All Around The World
# Scraping lyrics of All Around the World (Reprise)
# Scraping lyrics of All in The Mind
# Scraping lyrics of All You Need is Love
# Scraping lyrics of Angel Child
# Scraping lyrics of Bag It Up
# Scraping lyrics of Be Here Now
# Scraping lyrics of Better Let You Know
# Scraping lyrics of Better Man
# Scraping lyrics of Bonehead's Bank Holiday
# Scraping lyrics of Born on a Different Cloud
# Scraping lyrics of Bring It On Down
# Scraping lyrics of Can You See It Now? (I Can See It Now)
# Scraping lyrics of Carnation
# Scraping lyrics of Carry Us All
# Scraping lyrics of Cast No Shadow
# Scraping lyrics of Champagne Supernova
# Scraping lyrics of Chipper Sob
# Scraping lyrics of Cigarettes & Alcohol
# Scraping lyrics of Cigarettes in Hell
# Scraping lyrics of Cigarretes Alcohol
# Scraping lyrics of Cloudburst
# Scraping lyrics of Colour My Life
# Scraping lyrics of Columbia
# Scraping lyrics of Come Together
# Scraping lyrics of Comin' On Strong
# Scraping lyrics of Cum on Feel The Noize
# Scraping lyrics of D'yer Wanna Be A Spaceman
# Scraping lyrics of D'you Know What I Mean
# Scraping lyrics of D'You Know What I Mean? (Remastered)
# Scraping lyrics of Day Tripper
# Scraping lyrics of Digsy's Diner
# Scraping lyrics of Digsy's Dinner
# Scraping lyrics of Do You Know What I Mean
# Scraping lyrics of Don't Go Away
# Scraping lyrics of Don't Look Back In Anger
# Scraping lyrics of Eyeball Tickler
# Scraping lyrics of Fade Away
# Scraping lyrics of Fade In-Out
# Scraping lyrics of Falling Down
# Scraping lyrics of Flashbax
# Scraping lyrics of Force of Nature
# Scraping lyrics of Forces of Nature
# Scraping lyrics of Fuckin' In The Bushes
# Scraping lyrics of Full On
# Scraping lyrics of Gas Panic
# Scraping lyrics of Getting Older
# Scraping lyrics of Go Let It Out
# Scraping lyrics of Going Nowhere
# Scraping lyrics of Goodbye Cold World
# Scraping lyrics of Guess God Thinks I'm Abel
# Scraping lyrics of Half The World Away
# Scraping lyrics of Headshrinker
# Scraping lyrics of Hello
# Scraping lyrics of Help!
# Scraping lyrics of Helter Skelter
# Scraping lyrics of Heroes
# Scraping lyrics of Hey Hey, My My
# Scraping lyrics of Hey Now !
# Scraping lyrics of How Does It Feel
# Scraping lyrics of Hung in a Bad Place
# Scraping lyrics of I Am The Walrus
# Scraping lyrics of I Believe In All
# Scraping lyrics of I Can See A Liar
# Scraping lyrics of I Hope, I Think, I Know
# Scraping lyrics of I Hope, I Think, I Know (Remastered)
# Scraping lyrics of I Wanna Live A Dream
# Scraping lyrics of I Wanna Live In A Dream, In My Record Machine
# Scraping lyrics of I Will Believe
# Scraping lyrics of I Will Show You
# Scraping lyrics of I'm Only Sleeping
# Scraping lyrics of I'm Outta Time
# Scraping lyrics of Idler's Dream
# Scraping lyrics of It Must Have Been Love
# Scraping lyrics of It's a Crime
# Scraping lyrics of It's Better People
# Scraping lyrics of It's Gettin' Better (Man!!)
# Scraping lyrics of It's Getting Better
# Scraping lyrics of It's Getting Better, Man
# Scraping lyrics of It's Good, To Be Free
# Scraping lyrics of Just Getting Older
# Scraping lyrics of Keep The Dream Alive
# Scraping lyrics of Let Forever Be
# Scraping lyrics of Let There Be Love
# Scraping lyrics of Let's All Make Believe
# Scraping lyrics of Life in Vain
# Scraping lyrics of Listen Up
# Scraping lyrics of Little By Little
# Scraping lyrics of Little James
# Scraping lyrics of Live Forever
# Scraping lyrics of Lord Don't Slow Me Down
# Scraping lyrics of Love Like A Bomb
# Scraping lyrics of Lyla
# Scraping lyrics of Magic Pie
# Scraping lyrics of Manuk Dadali
# Scraping lyrics of Married With Children
# Scraping lyrics of Merry Xmas Everyone
# Scraping lyrics of Morning Glory
# Scraping lyrics of Mrs. Robinson
# Scraping lyrics of Mucky Fingers
# Scraping lyrics of Must Be The Music
# Scraping lyrics of My Big Mouth
# Scraping lyrics of My Generation
# Scraping lyrics of My Sister Lover
# Scraping lyrics of Nothin' On Me
# Scraping lyrics of One Way Road
# Scraping lyrics of Part Of The Queue
# Scraping lyrics of Pass Me Down The Wine
# Scraping lyrics of Put Yer Money Where Yer Mouth Is
# Scraping lyrics of Put Yer Money Where Your Mouth Is
# Scraping lyrics of Rock 'n' Roll Star
# Scraping lyrics of Rockin' Chair
# Scraping lyrics of Roll It Over
# Scraping lyrics of Roll With It
# Scraping lyrics of Round Are Way
# Scraping lyrics of Sad Song
# Scraping lyrics of Scorpio Rising
# Scraping lyrics of See The Sun
# Scraping lyrics of Setting Sun
# Scraping lyrics of Shakermaker
# Scraping lyrics of She is Electric
# Scraping lyrics of She is Love
# Scraping lyrics of She's Electric
# Scraping lyrics of Shout It Out Loud
# Scraping lyrics of Sittin' Here In Silence (On My Own)
# Scraping lyrics of Slide Away
# Scraping lyrics of Soldier On
# Scraping lyrics of Solve My Mystery
# Scraping lyrics of Some Might Say
# Scraping lyrics of Song Bird
# Scraping lyrics of Stand By Me
# Scraping lyrics of Stay Young
# Scraping lyrics of Step Out
# Scraping lyrics of Stop Crying Your Heart Out
# Scraping lyrics of Stop Crying Your Hearth Out
# Scraping lyrics of Stop The Clocks
# Scraping lyrics of Strange Thing
# Scraping lyrics of Street Fighting
# Scraping lyrics of Street Fighting Man
# Scraping lyrics of Sunday Morning Call
# Scraping lyrics of Supersonic
# Scraping lyrics of Take Me
# Scraping lyrics of Take Me Away
# Scraping lyrics of Talk Tonight
# Scraping lyrics of Thank You For The Good Times
# Scraping lyrics of The Boy With The Blues
# Scraping lyrics of The Cage
# Scraping lyrics of The Fame
# Scraping lyrics of The Fever
# Scraping lyrics of The Girl In The Dirty Shirt
# Scraping lyrics of The Hindu Times
# Scraping lyrics of The Importance Of Being Idle
# Scraping lyrics of The Masterplan
# Scraping lyrics of The Meaning Of Soul
# Scraping lyrics of The Nature of Reality
# Scraping lyrics of The Quiet Ones
# Scraping lyrics of The Shock Of The Lightning
# Scraping lyrics of The Swamp Song
# Scraping lyrics of The Turning
# Scraping lyrics of This Guy's in Love With You
# Scraping lyrics of Those Swollen Hand Blues
# Scraping lyrics of To Be Free
# Scraping lyrics of To Be Someone
# Scraping lyrics of To Be Where There's Life
# Scraping lyrics of Tomorrow Never Knows
# Scraping lyrics of Trouble
# Scraping lyrics of Turn Up The Sun
# Scraping lyrics of Underneath The Sky
# Scraping lyrics of Untiled 1
# Scraping lyrics of Untitled 2
# Scraping lyrics of Up In The Sky
# Scraping lyrics of Waiting For The Rapture
# Scraping lyrics of Wanderwall
# Scraping lyrics of What's The Story Morning Glory?
# Scraping lyrics of Whatever
# Scraping lyrics of Where Did It All Go Wrong?
# Scraping lyrics of Who Feels Love
# Scraping lyrics of Who Put the Weight of the World On My Shoulders?
# Scraping lyrics of Wonderwall
# Scraping lyrics of Wonderwall - Remastered
# Scraping lyrics of Wont Let You Down
# Scraping lyrics of You've Got To Hide Your Love Away

# %%
oasis_df = oasis_songs.join(oasis_lyrics, rsuffix = '_scrapped').drop(columns = 'title_scrapped')
oasis_df.head()
# Out:
#                             title  year  \
# 0  (Get Off Your) High Horse Lady  2008
# 1               (I Got) The Fever  2007
# 2      (Probably) All in the Mind  2008
# 3  (You've Got) A Heart Of A Star  2007
# 4                A Bell Will Ring  2005
#
#                                                  url popularity  \
# 0  http://www.metrolyrics.com/get-off-your-high-h...          0
# 1  http://www.metrolyrics.com/i-got-the-fever-lyr...          1
# 2  http://www.metrolyrics.com/probably-all-in-the...          0
# 3  http://www.metrolyrics.com/youve-got-a-heart-o...          4
# 4  http://www.metrolyrics.com/a-bell-will-ring-ly...          1
#
#                                                verse
# 0  Get off your high horse Lady, I don't need a r...
# 1  I'm tired of my life but my heads alright\nI g...
# 2  Show me who you are\nI'll show you what you lo...
# 3  You're never gonna get along, hanging out, thi...
# 4  A little space, a little time\nSee what it can...

# %%
oasis_df.to_csv('oasis_lyrics.csv', index = False)

# %% [markdown]
# # Cage the Elephant toooo

# %%
cte = scrap_songs_by_artist('cage-the-elephant', 1)
# Out:
# Scraping http://www.metrolyrics.com/cage-the-elephant-alpage-1.html

# %%
cte_lyrics = cte.apply(get_lyrics, axis = 1)
# Out:
# Scraping lyrics of 2024
# Scraping lyrics of 2024
# Scraping lyrics of Aberdeen
# Scraping lyrics of Aint No Rest For The Wicked
# Scraping lyrics of Always Something
# Scraping lyrics of Around My Head
# Scraping lyrics of Back Against The Wall
# Scraping lyrics of Back Stabbin' Betty
# Scraping lyrics of Black Madonna
# Scraping lyrics of Broken Boy
# Scraping lyrics of Cigarette Daydreams
# Scraping lyrics of Cold Cold Cold
# Scraping lyrics of Come A Little Closer
# Scraping lyrics of Cry Baby
# Scraping lyrics of Dance Dance
# Scraping lyrics of Dr. Dr. Dr.
# Scraping lyrics of Drones In The Valley
# Scraping lyrics of Flow
# Scraping lyrics of Free Love
# Scraping lyrics of Golden Brown
# Scraping lyrics of Goodbye
# Scraping lyrics of Halo
# Scraping lyrics of House of Glass
# Scraping lyrics of How Are You True
# Scraping lyrics of In One Ear
# Scraping lyrics of Indy Kidz
# Scraping lyrics of Instant Crush
# Scraping lyrics of It's Just Forever
# Scraping lyrics of James Brown
# Scraping lyrics of Japanese Buffalo
# Scraping lyrics of Judas
# Scraping lyrics of Lotus
# Scraping lyrics of Love's the Only Way
# Scraping lyrics of Mess Around
# Scraping lyrics of Night Running
# Scraping lyrics of Portuguese Knife Fight
# Scraping lyrics of Punchin' Bag
# Scraping lyrics of Ready to Let Go
# Scraping lyrics of Right Before My Dreams
# Scraping lyrics of Right Before My Eyes
# Scraping lyrics of Rubber Ball
# Scraping lyrics of Sabertooth Tiger
# Scraping lyrics of Sell Yourself
# Scraping lyrics of Shake Me Down
# Scraping lyrics of Shiver
# Scraping lyrics of Shiver Me Timber
# Scraping lyrics of Skin and Bones
# Scraping lyrics of Social Cues
# Scraping lyrics of Soil To The Sun
# Scraping lyrics of Spdierhead
# Scraping lyrics of Sweetie Little Jean
# Scraping lyrics of Take It Or Leave It
# Scraping lyrics of Tangle
# Scraping lyrics of Telescope
# Scraping lyrics of That's Right
# Scraping lyrics of The War Is Over
# Scraping lyrics of Tiny Little Robots
# Scraping lyrics of Tokyo Smoke
# Scraping lyrics of Too Late to Say Goodbye
# Scraping lyrics of Trouble
# Scraping lyrics of What I'm Becoming
# Scraping lyrics of Whole Wide World

# %%
cte_lyrics.to_csv('cage_the_elephant_lyrics.csv', index = False)
